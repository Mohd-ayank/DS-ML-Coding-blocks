# %%
print("hello python")

# %%
a=120
b=a
id(a)
# Out:
# 140721216551064

# %%
id(b)
# Out:
# 140721216551064

# %%
#different addresses but when we take a=10, b=10 then same id come for a and b.
a=10000
b=10000
id(a)
# Out:
# 1554324750928

# %%
id(b)
# Out:
# 1554324753392

# %%
#exception
a=10
b=10

# %%
id(a)
# Out:
# 140721216547544

# %%
id(b)
# Out:
# 140721216547544
