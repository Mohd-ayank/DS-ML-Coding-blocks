# %%
#covered numpy in 28_09, 10_04 and 10_05 
#matrix multiplixcation

# %%
import numpy as np
n1=np.arange(1,7).reshape(3,2)
n1
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
n2=np.arange(1,7).reshape(2,3)
n2
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
n1.dot(n2)
# Out:
# array([[ 9, 12, 15],
#        [19, 26, 33],
#        [29, 40, 51]])

# %%
n2.dot(n1)
# Out:
# array([[22, 28],
#        [49, 64]])

# %%
n1@n2
# Out:
# array([[ 9, 12, 15],
#        [19, 26, 33],
#        [29, 40, 51]])
