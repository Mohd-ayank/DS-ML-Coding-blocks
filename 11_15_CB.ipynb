# %%
#WEB SCRAPING (SCRAPING OF HTML FROM WEB PAGES) -> find and find_all

# %%
import requests
import bs4

# %%
print(bs4.__version__)
# Out:
# 4.13.4

# %%
simple_html_obj = """
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>ID and Class Example</title>
    <style>
        #main-title {
            color: blue;
        }

        .highlight {
            background-color: yellow;
        }
    </style>
</head>

<body>
        <h1 id="main-title">Welcome to My Page</h1>

    <p class="highlight">This paragraph uses a class.</p>

    <p class="highlight">This is another paragraph with the same class.</p>

    <p ayan="md">This paragraph has no class or id.</p>
</body>
</html>
"""

# %%
soup = bs4.BeautifulSoup(simple_html_obj)

print(soup.prettify())#indentation sahi kar deta hai
# Out:
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <title>
#    ID and Class Example
#   </title>
#   <style>
#    #main-title {
#             color: blue;
#         }
#
#         .highlight {
#             background-color: yellow;
#         }
#   </style>
#  </head>
#  <body>
#   <h1 id="main-title">
#    Welcome to My Page
#   </h1>
#   <p class="highlight">
#    This paragraph uses a class.
#   </p>
#   <p class="highlight">
#    This is another paragraph with the same class.
#   </p>
#   <p ayan="md">
#    This paragraph has no class or id.
#   </p>
#  </body>
# </html>

# %%
#find and findall
#obviuosly tags we will find out
#find the title of an article

# %%
#pehla vala para tag a jayega
para_tag = soup.find('p')

# %%
para_tag
# Out:
# <p class="highlight">This paragraph uses a class.</p>

# %%
para_tag.text
# Out:
# 'This paragraph uses a class.'

# %%
para_tag = soup.find('h1')
para_tag
# Out:
# <h1 id="main-title">Welcome to My Page</h1>

# %%
#I dont want the first one, I want the 3rd one
para_tag = soup.find('p', attrs={'ayan':'md'})
para_tag
# Out:
# <p ayan="md">This paragraph has no class or id.</p>

# %%
type(para_tag)
# Out:
# bs4.element.Tag

# %%
simple_html_obj = """
<html>
    <head></head>
    <body>
        <div id = "div1">
            <p id = 1>Hello</p>
            <p id = 2>World</p>
            <p id = 3 shub = cb>hello</p>
        </div>
        <div id = "div2">
            <p id = 4 shub = cb>world</p>
            <p id = 4>hello</p>
        </div>
    </body>
</html>
"""

# %%
soup=bs4.BeautifulSoup(simple_html_obj)

# %%
para_tag = soup.find('p',attrs={'id':'4', 'shub':'cb'})

# %%
print(para_tag)
# Out:
# <p id="4" shub="cb">world</p>

# %%
div_tag = soup.find('div', attrs={'id':'div2'})
print(div_tag.text)
# Out:
# world
# hello

# %%
div_tag.find('p') #scope is limited to div tag itself
# Out:
# <p id="4" shub="cb">world</p>

# %%
para_tag=soup.find_all('p')
para_tag
# Out:
# [<p id="1">Hello</p>,
#  <p id="2">World</p>,
#  <p id="3" shub="cb">hello</p>,
#  <p id="4" shub="cb">world</p>,
#  <p id="4">hello</p>]

# %%
for p_tag in para_tag:
    print(p_tag.attrs['id'], p_tag.text)
# Out:
# 1 Hello
# 2 World
# 3 hello
# 4 world
# 4 hello

# %%
para_tag = soup.div
type(para_tag)
# Out:
# bs4.element.Tag

# %%
para_tag
# Out:
# <div id="div1">
# <p id="1">Hello</p>
# <p id="2">World</p>
# <p id="3" shub="cb">hello</p>
# </div>

# %%
para_tag.name
# Out:
# 'div'

# %%
#https://webscraper.io/test-sites/tables
res=requests.get('https://webscraper.io/test-sites/tables')

# %%
print(res.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<!-- Google Tag Manager -->
# <script nonce="uRAAQ5aZHwesi111iz37lnPybF8h1HuN">(function (w, d, s, l, i) {
# 		w[l] = w[l] || [];
# 		w[l].push({
# 			'gtm.start':
# 				new Date().getTime(), event: 'gtm.js'
# 		});
# 		var f = d.getElementsByTagName(s)[0],
# 			j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
# 		j.async = true;
# 		j.src =
# 			'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
# 		f.parentNode.insertBefore(j, f);
# 	})(window, document, 'script', 'dataLayer', 'GTM-NVFPDWB');</script>
# <!-- End Google Tag Manager -->
# 	<title>Table Playground | Web Scraper Test Sites</title>
# 	<meta charset="utf-8">
# 	<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#
# 	<meta name="keywords"
# 		  content="web scraping,Web Scraper,Chrome extension,Crawling,Cross platform scraper"/>
# 	<meta name="description"
# ...

# %%
soup=bs4.BeautifulSoup(res.text)
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <!-- Google Tag Manager -->
# <script nonce="uRAAQ5aZHwesi111iz37lnPybF8h1HuN">(function (w, d, s, l, i) {
# 		w[l] = w[l] || [];
# 		w[l].push({
# 			'gtm.start':
# 				new Date().getTime(), event: 'gtm.js'
# 		});
# 		var f = d.getElementsByTagName(s)[0],
# 			j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
# 		j.async = true;
# 		j.src =
# 			'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
# 		f.parentNode.insertBefore(j, f);
# 	})(window, document, 'script', 'dataLayer', 'GTM-NVFPDWB');</script>
# <!-- End Google Tag Manager -->
# <title>Table Playground | Web Scraper Test Sites</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="web scraping,Web Scraper,Chrome extension,Crawling,Cross platform scraper" name="keywords">
# ...

# %%
row_tag=soup.find('tr')
row_tag
# Out:
# <tr>
# <th>#</th>
# <th>First Name</th>
# <th>Last Name</th>
# <th>Username</th>
# </tr>

# %%
row_tag.text
# Out:
# '\n#\nFirst Name\nLast Name\nUsername\n'

# %%
row_tag=soup.find_all('tr')

for rows in row_tag:
    print(rows.text)
    print()
# Out:
# #
# First Name
# Last Name
# Username
#
#
#
# 1
# Mark
# Otto
# @mdo
#
#
#
# 2
# Jacob
# Thornton
# @fat
#
#
#
# 3
# Larry
# the Bird
# @twitter
#
#
#
# #
# First Name
# Last Name
# Username
#
#
#
# 4
# Harry
# Potter
# @hp
#
#
#
# 5
# John
# Snow
# @dunno
#
#
#
# 6
# Tim
# Bean
# @timbean

# %%
#homework - list of sovereign states -> pura data 2-d me leke ana

# %%
table_tags= soup.find_all('table')
table_tags[0]
# Out:
# <table class="table table-bordered">
# <thead>
# <tr>
# <th>#</th>
# <th>First Name</th>
# <th>Last Name</th>
# <th>Username</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>1</td>
# <td>Mark</td>
# <td>Otto</td>
# <td>@mdo</td>
# </tr>
# <tr>
# <td>2</td>
# <td>Jacob</td>
# <td>Thornton</td>
# <td>@fat</td>
# </tr>
# <tr>
# <td>3</td>
# <td>Larry</td>
# <td>the Bird</td>
# <td>@twitter</td>
# </tr>
# </tbody>
# </table>

# %%
table[1]
# Out:
# <table class="table table-bordered table-bordered2">
# <thead>
# <tr>
# <th>#</th>
# <th>First Name</th>
# <th>Last Name</th>
# <th>Username</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>4</td>
# <td>Harry</td>
# <td>Potter</td>
# <td>@hp</td>
# </tr>
# <tr>
# <td>5</td>
# <td>John</td>
# <td>Snow</td>
# <td>@dunno</td>
# </tr>
# <tr>
# <td>6</td>
# <td>Tim</td>
# <td>Bean</td>
# <td>@timbean</td>
# </tr>
# </tbody>
# </table>

# %%
tb=table_tags[0]
tb
# Out:
# <table class="table table-bordered">
# <thead>
# <tr>
# <th>#</th>
# <th>First Name</th>
# <th>Last Name</th>
# <th>Username</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>1</td>
# <td>Mark</td>
# <td>Otto</td>
# <td>@mdo</td>
# </tr>
# <tr>
# <td>2</td>
# <td>Jacob</td>
# <td>Thornton</td>
# <td>@fat</td>
# </tr>
# <tr>
# <td>3</td>
# <td>Larry</td>
# <td>the Bird</td>
# <td>@twitter</td>
# </tr>
# </tbody>
# </table>

# %%
#for thead
#tb.find('thead')
#or
tb.thead.text
# Out:
# '\n\n#\nFirst Name\nLast Name\nUsername\n\n'

# %%
table_data= []
row=[]
for th in tb.thead.find_all('th'):
    row.append(th.text)
table_data.append(row)

# %%
table_data
# Out:
# [['#', 'First Name', 'Last Name', 'Username']]

# %%
table_data = []
for tr in tb.tbody.find_all('tr'):
    row=[]
    for td in tr.find_all('td'):
        row.append(td.text)
    table_data.append(row)
    
table_data
# Out:
# [['1', 'Mark', 'Otto', '@mdo'],
#  ['2', 'Jacob', 'Thornton', '@fat'],
#  ['3', 'Larry', 'the Bird', '@twitter']]

# %%
every_table=[]

for table in table_tags:
    table_data = []
    for tr in table.tbody.find_all('tr'):
        row=[]
        for td in tr.find_all('td'):
            row.append(td.text)
        table_data.append(row)
    every_table.append(table_data)
#put head in in table also
#either use a header int outer or use flag and put header inside of the loop

# %%
every_table
# Out:
# [[['1', 'Mark', 'Otto', '@mdo'],
#   ['2', 'Jacob', 'Thornton', '@fat'],
#   ['3', 'Larry', 'the Bird', '@twitter']],
#  [['4', 'Harry', 'Potter', '@hp'],
#   ['5', 'John', 'Snow', '@dunno'],
#   ['6', 'Tim', 'Bean', '@timbean']]]

# %%
#how to store this data in csv
#by using data fromae or any other way
import pandas as pd
data=[]
for tb in every_table:
    for tr in tb:
        data.append(tr)
data
# Out:
# [['1', 'Mark', 'Otto', '@mdo'],
#  ['2', 'Jacob', 'Thornton', '@fat'],
#  ['3', 'Larry', 'the Bird', '@twitter'],
#  ['4', 'Harry', 'Potter', '@hp'],
#  ['5', 'John', 'Snow', '@dunno'],
#  ['6', 'Tim', 'Bean', '@timbean']]

# %%
tdata=pd.DataFrame(data[1:], columns=data[0])#put column of 1st row then only dropping of 1st row
tdata
# Out:
#    1   Mark      Otto      @mdo
# 0  2  Jacob  Thornton      @fat
# 1  3  Larry  the Bird  @twitter
# 2  4  Harry    Potter       @hp
# 3  5   John      Snow    @dunno
# 4  6    Tim      Bean  @timbean
