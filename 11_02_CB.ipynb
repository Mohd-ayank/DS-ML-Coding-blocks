# %%
#go through multiple case studies and use chatgpt

# %%
import seaborn as sns
tips_data = sns.load_dataset('tips')
tips_data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.histplot(tips_data, x='total_bill', kde=True)
#kernel density estimation
#log-normal distribution
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(tips_data, x='total_bill', kde=True, hue='time')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(tips_data, x='tip', kde=True, hue='time')
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(tips_data, x='tip', kde=True, hue='sex')
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(tips_data, x='tip', kde=True, hue='day')
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(tips_data, x='tip', y='total_bill')#graph is divided in square grids form
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.kdeplot(tips_data, x='total_bill', hue='day')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(tips_data, x='tip', y='total_bill')
#mountain models
#terrain models and trenches
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.scatterplot(data=tips_data, x='total_bill', y='tip', hue='time')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips_data, x='total_bill', y='tip', hue='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips_data, x='total_bill', y='tip', hue='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#to represent signals
plt.figure(figSize=(10,4))
sns.lineplot(data=fmri_data, x='timepoint',y='signal', hue='event', style='region')
plt.grid()
plt.show()

# %%
sns.lineplot(data=fmri_data, x='timepoint', y='signal', hue='event', style='region', markers=['X', '*'])

# %%
sns.lineplot(data=fmri_data, x='timepoint', y='signal')

# %%
sns.jointplot(tips_data, x='total_bill', y='tip')#multiple graphs i the same plot

# %%
#kde='hex'
#regression -> try to fit the data (prediction)
#king='reg'

# %%
#comparison between multiple variables
#not used for deep analysis
sns.pairplot(tips_data)

# %%
sns.boxplot(tips_data, x='day', y='total_bill', hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#IQR -> helps to detect outliers (an algorithm)
sns.violinplot(t)
#inside this boxplot lies

# %%
sns.stripplot()
# Out:
# <Axes: >

# %%
sns.stripplot(ti

# %%
sns.swarmplot()

# %%
flights_data = sns.load_dataset('flights')
flights_data
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
nfd=flights_data.pivot_table(index='month', )
# Out:
# C:\Users\realme\AppData\Local\Temp\ipykernel_10444\2173360708.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   nfd=flights_data.pivot_table(index='month')

# %%
sns.heatmap(nfd)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 sns.heatmap(nfd)
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.countplot()
