# %%
#sets
s={"QEW",1,23}
s
# Out:
# {1, 23, 'QEW'}

# %%
#dictionary
l=[1,1,1,2,2,3,4,1,2,3,6,2,3,5,1,3,4,3,4,2,4,2,3,3,4,1,3]
d={}
for ele in l:
    if d.get(ele)!=None:#if ele in d
        d[ele]+=1
    else:
        d[ele]=1
print(d)
# Out:
# {1: 6, 2: 6, 3: 8, 4: 5, 6: 1, 5: 1}

# %%
#for ele in l:
    #d[ele]=d.get(ele,0)+1

# %%
d={}
for i in  range(10):
    d[i]=i**2
d
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %%
#dictionary comprehension
c= {i:i**2 for i in range(10)}
c
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %%
s= {i:i*2+7 for i in range(10) if i%2==0}
s
# Out:
# {0: 7, 2: 11, 4: 15, 6: 19, 8: 23}

# %%
#comparing two dictionaries
# for ele in d1:
#     if d1[ele]!=d2.get(ele):
# or use d1==d2
