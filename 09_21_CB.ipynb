# %%
#file handling

# %%
file=open('demo.txt')

# %%
print(file)
# Out:
# <_io.TextIOWrapper name='demo.txt' mode='r' encoding='cp1252'>

# %%
print(type(file))
# Out:
# <class '_io.TextIOWrapper'>

# %%
print(file.read())
# Out:
# This is a demo file
# batch CB DS ML

# %%
file.close()
